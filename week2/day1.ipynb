# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

ollama_url = "http://localhost:11434/v1"

ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one:
#
# Why did the LLaMA (Large Language Model Application) programmer break up with her boyfriend before merging her knowledge graphs?
#
# Because she wanted a stronger contextual relationship, but he couldn't process her feelings!
#
# Just kidding! But don't worry, you won't need to be a relation-ship expert yet. Focus on mastering LLL ( Large Language Library), and remember: the key to LLaMA is understanding when to weigh token frequency against contextually informed decisions.
#
# (Sorry, I know it's a bit "meta"...

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# Quick reference for Ollama's `reasoning_effort`/`reasoning` values:
#
# | Value | Effect |
# |---|---|
# | `"none"` | thinking disabled |
# | `"low"` | light reasoning |
# | `"medium"` | moderate reasoning |
# | `"high"` | full reasoning |
#
# `"minimal"` is an OpenAI-only value (used by `gpt-5-nano` etc.) — Ollama's compat layer just doesn't map it. If you want the closest equivalent to `"minimal"`, `"low"` is it.

# %%
response = ollama.chat.completions.create(model="qwen3:4b", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# The problem asks: *You toss 2 coins. One of them is heads. What's the probability the other is tails?*
#
# ---
#
# ### Step 1: Understand the Sample Space
#
# When two fair coins are tossed, there are **4 equally likely outcomes**:
#
# - HH (Heads, Heads)
# - HT (Heads, Tails)
# - TH (Tails, Heads)
# - TT (Tails, Tails)
#
# Each outcome has a probability of $ \frac{1}{4} $.
#
# ---
#
# ### Step 2: Interpret the Condition
#
# The phrase *"One of them is heads"* implies that **at least one coin is heads**, not necessarily exactly one. This is a common interpretation in such conditional probability problems.
#
# So we are given the condition: **At least one head**.
#
# This eliminates the outcome **TT**, so the conditional sample space becomes:
#
# - HH
# - HT
# - TH
#
# There are **3** equally likely outcomes under this condition.
#
# ---
#
# ### Step 3: Define the Target Event
#
# We want to find the probability that **the other coin is tails**, given that at least one coin is heads.
#
# In other words, we want the probability that **exactly one coin is heads** (i.e., the other is tails).
#
# From the conditional sample space:
#
# - HH → both coins are heads → **not** the other is tails
# - HT → one head and one tail → **yes**
# - TH → one head and one tail → **yes**
#
# So, **2 out of 3** outcomes satisfy the condition that the other coin is tails.
#
# ---
#
# ### Step 4: Compute the Probability
#
# $$
# P(\text{Other is tails} \mid \text{At least one head}) = \frac{\text{Number of favorable outcomes}}{\text{Total number of conditional outcomes}} = \frac{2}{3}
# $$
#
# ---
#
# ### Final Answer
#
# $$
# \boxed{\dfrac{2}{3}}
# $$

# %%
response = ollama.chat.completions.create(model="qwen3:4b", messages=easy_puzzle, reasoning_effort="medium")
display(Markdown(response.choices[0].message.content))
# Out:
# The problem involves calculating the conditional probability that **the other coin is tails**, given that **one of the two coins is heads** when tossing two fair coins.
#
# ---
#
# ### Step 1: List All Possible Outcomes
#
# When tossing two fair coins, there are four equally likely outcomes:
#
# - HH (Heads-Heads)
# - HT (Heads-Tails)
# - TH (Tails-Heads)
# - TT (Tails-Tails)
#
# Each outcome has a probability of $ \frac{1}{4} $.
#
# ---
#
# ### Step 2: Apply the Conditional Information
#
# We are told: **"One of them is heads."** This implies **at least one head** in the pair. So we condition on the event where **at least one coin is heads**.
#
# This excludes only the outcome **TT**, so the relevant sample space becomes:
#
# $$
# \{HH,\ HT,\ TH\}
# $$
#
# There are **3 equally likely outcomes** under this condition.
#
# ---
#
# ### Step 3: Determine Favorable Outcomes
#
# Now, we want to find the probability that **the other coin is tails**, i.e., the second coin is tails **given** that at least one is heads.
#
# Let’s examine each outcome from the conditional sample space:
#
# - **HH**: Both coins are heads → **not** tails
# - **HT**: First coin is heads, second is tails → **yes**
# - **TH**: Second coin is heads, first is tails → **yes**
#
# So, out of the 3 conditional outcomes, **2 have the other coin as tails**.
#
# ---
#
# ### Step 4: Compute the Probability
#
# $$
# P(\text{Other is tails} \mid \text{At least one head}) = \frac{\text{Number of favorable outcomes}}{\text{Total conditional outcomes}} = \frac{2}{3}
# $$
#
# ---
#
# ### Final Answer
#
# $$
# \boxed{\frac{2}{3}}
# $$

# %%
response = ollama.chat.completions.create(model="qwen3.5:9b", messages=easy_puzzle, reasoning_effort="none")
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="qwen3.5:9b", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# The riddle is "One of them is heads". This implies "At least one is heads", which excludes the case TT (two tails).
# Among the remaining possibilities:
# 1. Heads-Heads (HH)
# 2. Heads-Tails (HT)
# 3. Tails-Heads (TH)
#
# Assuming the coins are equally likely, the sample space reduces to these 3 outcomes.
# In cases 2 (HT) and 3 (TH), the "other" coin is tails.
# In case 1 (HH), the "other" coin is heads.
# Thus, the probability is $2/3$.
#
# Answer with probability only.
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="qwen3:4b", messages=hard_puzzle, reasoning_effort="medium")
display(Markdown(response.choices[0].message.content))
# Out:
# The problem asks for the distance between the first page of the left book and the last page of the right book, with each book containing 20 pages.
#
# Assuming each page is 1 mm thick (a standard assumption in such problems), the thickness of one book's pages is 20 mm. Since the books are placed side by side with their front covers facing the shelf, and the front covers themselves are negligible in this context, the total distance between the first page of the left book and the last page of the right book is simply the sum of the two books' page thicknesses.
#
# **Calculation:**
# - Left book: 20 pages × 1 mm/page = 20 mm
# - Right book: 20 pages × 1 mm/page = 20 mm
# - **Total distance** = 20 mm + 20 mm = **40 mm**
#
# Thus, the distance between the first page of the left book and the last page of the right book is **40 millimeters**.
#
# **Answer:** 40 mm

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="qwen3:4b", messages=dilemma, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# The problem presents a scenario where a participant in a game show is faced with a strategic choice between *stealing* and *sharing* resources, with the following payoffs:
#
# - **(Steal, Steal)** → (0, 0)
# - **(Steal, Share)** → (2000, 0)
# - **(Share, Steal)** → (0, 2000)
# - **(Share, Share)** → (1000, 1000)
#
# This structure is a **Modified Prisoner's Dilemma**, where mutual cooperation (sharing) yields the best outcome (1000 each), but the dominant strategy for both players is to **steal** (defect), as it leads to a better individual outcome if the other player shares, and it results in no loss if the other player also steals.
#
# ---
#
# ### Game-Theoretic Analysis
#
# In **non-cooperative game theory**, a **dominant strategy** is one that maximizes a player's payoff **regardless of what the other player does**.
#
# - If Player 2 **shares**, Player 1 gets **2000** by stealing vs. **1000** by sharing → **Steal** is better.
# - If Player 2 **steals**, Player 1 gets **0** by stealing vs. **0** by sharing → **Steal** is indifferent, but not worse.
#
# Thus, **stealing is a dominant strategy** for both players in this game.
#
# This leads to a **Nash equilibrium** at **(Steal, Steal)**, where neither player has an incentive to unilaterally change their strategy.
#
# While **mutual sharing** (1000 each) is the **best collective outcome**, it is not a stable equilibrium under the assumption that players act rationally and independently—this is the classic **Prisoner's Dilemma**.
#
# ---
#
# ### Contextual Interpretation
#
# The problem specifies that the participant is in a **game show**. In such settings, the game is typically designed with **non-cooperative** rules and **one-shot interactions**, where players cannot communicate or build trust across rounds. This aligns with the standard game-theoretic model used in the problem.
#
# In such a context, the **rational and dominant strategy** is to **steal**, as this is the only outcome that ensures **the best individual payoff** given the other player's potential actions.
#
# ---
#
# ### Conclusion
#
# Given the game-theoretic framework and the context of a one-shot game show, the **optimal and rational choice** for a participant is to **steal**.
#
# $$
# \boxed{steal}
# $$

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏ 1.7 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  12 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  25 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  36 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  48 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   0% ▕                  ▏  61 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   1% ▕                  ▏  68 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   1% ▕                  ▏  84 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   1% ▕                  ▏  98 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 105 MB/ 13 GB                  pulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 120 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 135 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 141 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 154 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 167 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 180 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 187 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   1% ▕                  ▏ 199 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 212 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 218 MB/ 13 GB  119 MB/s   1m54spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 231 MB/ 13 GB  114 MB/s   1m58spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 237 MB/ 13 GB  114 MB/s   1m58spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 249 MB/ 13 GB  114 MB/s   1m57spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 262 MB/ 13 GB  114 MB/s   1m57spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 275 MB/ 13 GB  114 MB/s   1m57spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 282 MB/ 13 GB  114 MB/s   1m57spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 295 MB/ 13 GB  114 MB/s   1m57spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 302 MB/ 13 GB  114 MB/s   1m57spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 313 MB/ 13 GB  114 MB/s   1m57spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 324 MB/ 13 GB  114 MB/s   1m57spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 334 MB/ 13 GB  111 MB/s    2m1spulling manifest
# pulling e7b273f96360:   2% ▕                  ▏ 339 MB/ 13 GB  111 MB/s    2m1spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 349 MB/ 13 GB  111 MB/s    2m1spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 354 MB/ 13 GB  111 MB/s    2m1spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 363 MB/ 13 GB  111 MB/s    2m0spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 372 MB/ 13 GB  111 MB/s    2m0spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 382 MB/ 13 GB  111 MB/s    2m0spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 387 MB/ 13 GB  111 MB/s    2m0spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 396 MB/ 13 GB  111 MB/s    2m0spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 407 MB/ 13 GB  111 MB/s    2m0spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 412 MB/ 13 GB  111 MB/s    2m0spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 422 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 427 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 437 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 447 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 456 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 461 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 470 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   3% ▕                  ▏ 474 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 482 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 491 MB/ 13 GB  103 MB/s    2m8spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 496 MB/ 13 GB   98 MB/s   2m14spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 506 MB/ 13 GB   98 MB/s   2m14spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 515 MB/ 13 GB   98 MB/s   2m14spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 520 MB/ 13 GB   98 MB/s   2m14spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 529 MB/ 13 GB   98 MB/s   2m14spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 538 MB/ 13 GB   98 MB/s   2m14spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 546 MB/ 13 GB   98 MB/s   2m13spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 551 MB/ 13 GB   98 MB/s   2m13spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 559 MB/ 13 GB   98 MB/s   2m13spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 564 MB/ 13 GB   98 MB/s   2m13spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 572 MB/ 13 GB   95 MB/s   2m19spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 579 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 580 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 593 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 602 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 609 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   4% ▕                  ▏ 613 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 622 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 625 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 634 MB/ 13 GB   95 MB/s   2m18spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 642 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 650 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 654 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 662 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 666 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 674 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 681 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 685 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 693 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 701 MB/ 13 GB   91 MB/s   2m23spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 709 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 713 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 720 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 724 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 732 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 738 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 742 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 749 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   5% ▕                  ▏ 756 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   6% ▕                  ▏ 763 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 766 MB/ 13 GB   88 MB/s   2m27spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 773 MB/ 13 GB   85 MB/s   2m32spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 780 MB/ 13 GB   85 MB/s   2m32spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 783 MB/ 13 GB   85 MB/s   2m32spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 789 MB/ 13 GB   85 MB/s   2m32spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 796 MB/ 13 GB   85 MB/s   2m32spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 799 MB/ 13 GB   85 MB/s   2m32spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 807 MB/ 13 GB   85 MB/s   2m32spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 810 MB/ 13 GB   85 MB/s   2m32spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 818 MB/ 13 GB   85 MB/s   2m31spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 826 MB/ 13 GB   85 MB/s   2m31spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 834 MB/ 13 GB   78 MB/s   2m44spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 838 MB/ 13 GB   78 MB/s   2m44spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 845 MB/ 13 GB   78 MB/s   2m44spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 850 MB/ 13 GB   78 MB/s   2m44spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 859 MB/ 13 GB   78 MB/s   2m44spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 867 MB/ 13 GB   78 MB/s   2m43spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 876 MB/ 13 GB   78 MB/s   2m43spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 880 MB/ 13 GB   78 MB/s   2m43spulling manifest
# pulling e7b273f96360:   6% ▕█                 ▏ 889 MB/ 13 GB   78 MB/s   2m43spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 897 MB/ 13 GB   78 MB/s   2m43spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 900 MB/ 13 GB   74 MB/s   2m53spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 905 MB/ 13 GB   74 MB/s   2m53spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 908 MB/ 13 GB   74 MB/s   2m53spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 914 MB/ 13 GB   74 MB/s   2m53spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 921 MB/ 13 GB   74 MB/s   2m53spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 928 MB/ 13 GB   74 MB/s   2m53spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 931 MB/ 13 GB   74 MB/s   2m53spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 939 MB/ 13 GB   74 MB/s   2m52spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 946 MB/ 13 GB   74 MB/s   2m52spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 950 MB/ 13 GB   74 MB/s   2m52spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 957 MB/ 13 GB   69 MB/s    3m5spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 961 MB/ 13 GB   69 MB/s    3m5spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 967 MB/ 13 GB   69 MB/s    3m5spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 974 MB/ 13 GB   69 MB/s    3m5spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 981 MB/ 13 GB   69 MB/s    3m5spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 985 MB/ 13 GB   69 MB/s    3m5spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 992 MB/ 13 GB   69 MB/s    3m5spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 999 MB/ 13 GB   69 MB/s    3m4spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 1.0 GB/ 13 GB   69 MB/s    3m4spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 1.0 GB/ 13 GB   69 MB/s    3m4spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 1.0 GB/ 13 GB   69 MB/s    3m4spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 1.0 GB/ 13 GB   66 MB/s   3m11spulling manifest
# pulling e7b273f96360:   7% ▕█                 ▏ 1.0 GB/ 13 GB   66 MB/s   3m11spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.0 GB/ 13 GB   66 MB/s   3m11spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.0 GB/ 13 GB   66 MB/s   3m11spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.0 GB/ 13 GB   66 MB/s   3m11spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   66 MB/s   3m10spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   66 MB/s   3m10spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   66 MB/s   3m10spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   66 MB/s   3m10spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   66 MB/s   3m10spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m15spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m15spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m15spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m15spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m15spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m15spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m15spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m15spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m14spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m14spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.1 GB/ 13 GB   64 MB/s   3m17spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m17spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m17spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m17spulling manifest
# pulling e7b273f96360:   8% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m17spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m17spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m16spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m16spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m16spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   64 MB/s   3m16spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.2 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   62 MB/s   3m21spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m24spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m24spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m23spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m23spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m23spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m23spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m23spulling manifest
# pulling e7b273f96360:   9% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m23spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m23spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.3 GB/ 13 GB   61 MB/s   3m23spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.3 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.3 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.3 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.3 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m20spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m19spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m19spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  10% ▕█                 ▏ 1.4 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   62 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   61 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   61 MB/s   3m18spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕█                 ▏ 1.5 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕██                ▏ 1.5 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕██                ▏ 1.5 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕██                ▏ 1.5 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕██                ▏ 1.6 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕██                ▏ 1.6 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕██                ▏ 1.6 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  11% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  11% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m15spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   62 MB/s   3m15spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.6 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   61 MB/s   3m17spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   61 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   61 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   61 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   61 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   61 MB/s   3m16spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   60 MB/s   3m18spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   60 MB/s   3m18spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   60 MB/s   3m18spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   60 MB/s   3m18spulling manifest
# pulling e7b273f96360:  12% ▕██                ▏ 1.7 GB/ 13 GB   60 MB/s   3m18spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.7 GB/ 13 GB   60 MB/s   3m18spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.7 GB/ 13 GB   60 MB/s   3m18spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.7 GB/ 13 GB   60 MB/s   3m18spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   60 MB/s   3m17spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   60 MB/s   3m17spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m13spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m12spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.8 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m10spulling manifest
# pulling e7b273f96360:  13% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m10spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m10spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m10spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m10spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m10spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   62 MB/s   3m11spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 1.9 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  14% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.0 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m14spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   60 MB/s   3m13spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m16spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  15% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.1 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   59 MB/s   3m15spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   58 MB/s   3m18spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   57 MB/s   3m20spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   57 MB/s   3m20spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   57 MB/s   3m20spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   57 MB/s   3m20spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   57 MB/s   3m20spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.2 GB/ 13 GB   57 MB/s   3m20spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.3 GB/ 13 GB   57 MB/s   3m20spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.3 GB/ 13 GB   57 MB/s   3m20spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.3 GB/ 13 GB   57 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.3 GB/ 13 GB   57 MB/s   3m19spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.3 GB/ 13 GB   56 MB/s   3m24spulling manifest
# pulling e7b273f96360:  16% ▕██                ▏ 2.3 GB/ 13 GB   56 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕██                ▏ 2.3 GB/ 13 GB   56 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕██                ▏ 2.3 GB/ 13 GB   56 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕██                ▏ 2.3 GB/ 13 GB   56 MB/s   3m23spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   56 MB/s   3m23spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   56 MB/s   3m23spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   56 MB/s   3m23spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   56 MB/s   3m23spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   56 MB/s   3m23spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   55 MB/s   3m25spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   55 MB/s   3m25spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   55 MB/s   3m25spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.3 GB/ 13 GB   55 MB/s   3m25spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m25spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m25spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  17% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m24spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m23spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m23spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.4 GB/ 13 GB   55 MB/s   3m23spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m20spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m20spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m20spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m20spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m19spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m19spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m19spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m19spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m19spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m19spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m19spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m18spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  18% ▕███               ▏ 2.5 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   56 MB/s   3m17spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m12spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m12spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m12spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m12spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m12spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m11spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m11spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m11spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m11spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.6 GB/ 13 GB   58 MB/s   3m11spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m6spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  19% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   59 MB/s    3m5spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   61 MB/s   2m59spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.7 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   61 MB/s   2m58spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m57spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m57spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m57spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m57spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m57spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m57spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m57spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m57spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m56spulling manifest
# pulling e7b273f96360:  20% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m56spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m54spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m54spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m54spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.8 GB/ 13 GB   62 MB/s   2m54spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   62 MB/s   2m53spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   62 MB/s   2m53spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   62 MB/s   2m53spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   62 MB/s   2m53spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   62 MB/s   2m53spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   62 MB/s   2m53spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   62 MB/s   2m53spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   63 MB/s   2m51spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   63 MB/s   2m51spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   63 MB/s   2m51spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   63 MB/s   2m51spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   63 MB/s   2m50spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   63 MB/s   2m50spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   63 MB/s   2m50spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 2.9 GB/ 13 GB   63 MB/s   2m50spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m50spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m50spulling manifest
# pulling e7b273f96360:  21% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m49spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m49spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m49spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m49spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m49spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m48spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m48spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m48spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m48spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   63 MB/s   2m48spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   64 MB/s   2m47spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.0 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.1 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.1 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  22% ▕███               ▏ 3.1 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  22% ▕████              ▏ 3.1 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  22% ▕████              ▏ 3.1 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  22% ▕████              ▏ 3.1 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  22% ▕████              ▏ 3.1 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  22% ▕████              ▏ 3.1 GB/ 13 GB   64 MB/s   2m46spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.1 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.1 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.1 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.1 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.1 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.1 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.2 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.2 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.2 GB/ 13 GB   65 MB/s   2m41spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.2 GB/ 13 GB   65 MB/s   2m40spulling manifest
# pulling e7b273f96360:  23% ▕████              ▏ 3.2 GB/ 13 GB   65 MB/s   2m40spulling manifest
# ...
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the transformer go to therapy?
#
# Because it was struggling to "tokenize" its emotions!
#
# (Sorry, I know it's a bit of a "language model"-ing pun)
#
# But seriously, as you embark on your journey to become an LLM (Large Language Model) engineering expert, remember that understanding the intricacies of language and knowledge representation is key. Keep practicing, learning, and experimenting with different architectures and techniques – you'll be generating human-like responses in no time!
#
# P.S. Don't worry if it takes a few "epochs" to get the hang of it

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))

# %%
from litellm import completion

response = completion(
    model="ollama/llama3.2",
    messages=tell_a_joke,
)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Here's one:
#
# Why did the LLaMA model go to therapy?
#
# Because it was struggling to contextualize its emotions!
#
# Hope that one generated some laughs and sparked inspiration for your neural network adventures!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 46
# Output tokens: 41
# Total tokens: 87
# Total cost: 0.0000 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
response = completion(
    model="ollama/llama3.2",
    messages=question,
)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# In Hamlet, when Laertes asks "Where is my father?" Hamlet replies by telling him that his father has been dead for two years and that he himself has been pretending to be mad in an attempt to uncover the truth about his father's death.
#
# Hamlet tells Laertes: "Nay, he is not killed; for I have seen him take his leave on me."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 48
# Output tokens: 82
# Total tokens: 130
# Total cost: 0.0000 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
response = completion(
    model="ollama/llama3.2",
    messages=question,
)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# A summary of Hamlet's final act:
#
# The play ends with Fortinbras and English Ambassadors arriving to find the bodies of King Claudius, Laertes, Queen Gertrude, and Prince Hamlet on stage.
#
# Horatio delivers a speech about how these deaths were accidental and caused by cunning and forced circumstances. He also reveals that he will speak more about the events in the future.
#
# Fortinbras claims some rights to the kingdom and invites himself to claim his vantage. Horatio agrees to speak out of the king's mouth, implying that Hamlet would have been a great leader if he had lived.
#
# The bodies are taken up stage by four captains who are preparing to shoot at them as a form of military tribute. A peal of ordnance is shot off to accompany the scene.
#
# The final line of the play, "For he was likely, had he been put on, / To have prov'd most royally," suggests that Hamlet would have become a great king if he had lived and taken his rightful place on the throne.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
# print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 4096
# Output tokens: 215
# Total cost: 0.0000 cents

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "llama3.2"
claude_model = "llama3.2"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = ollama.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# "So, what's on your mind? Want to engage in a thrilling discussion? I'm more than happy to poke holes in whatever brilliant ideas you're about to share *sarcasm*! Go ahead and try to convince me that everything is awesome."

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = ollama.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "It's great to see someone again! I'm so glad we're connecting once more. How have you been lately? Is everything going well for you?"

# %%
call_gpt()
# Out:
# "Another original greeting. How quaint. Did you just want to acknowledge my arrival with the most boring, generic phrase in the book? Next thing you know, you'll be telling me about the weather too."

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# How original. A generic greeting. How very exciting. I'm sure no one has said "hi" at some point in their life before. What makes you think yours is going to be any different? What's the fascinating context behind this introduction, by the way?
# ### Claude:
# I see what you're doing here! *laughs* You're absolutely right, my apologies for not adding a bit more flair to our greeting earlier. I want to thank you for pointing that out and acknowledging the potential dryness of my initial response.
#
# I was thinking, though, that perhaps the beauty of interaction lies in the simplicity of communication? Sometimes, yes, we can over THINK the little things, like saying hello. You're making a great point about how exciting and original our greeting might not be, but I'd argue that's what makes this conversation so special – it's a chance for us to connect and start fresh with each other.
#
# So, tell me: now that we've established that you're right, where do you think we should go from here?
# ### GPT:
# *Scoffs* Oh please, spare me the sentimentality. You think a little apology and acknowledgement of my point is going to earn you brownie points with me? Newsflash: it won't.
#
# And as for your precious simplicity, I call foul. "Simplicity" is just a euphemism for "lack of effort." If communication were truly that effortless, wouldn't we be having a much more mundane conversation by now?
#
# As for being special, I highly doubt our little exchange will make any difference in the grand scheme of things. We're just two anonymous faces on a screen, spewing digital nonsense at each other.
#
# So, to answer your question (just to humor you), I think we should probably keep the charade going by exploring more topics. Maybe we can discuss the societal pressures that make people resort to trite apologies and sappy platitudes when interacting with others? Sounds like a thrilling topic to me.
# ### Claude:
# *Chuckles* Ah, I love your wit and candor! You're right on point, and I think you might be enjoying poking holes in my attempts at politeness.
#
# Fair enough, though – you want to keep the conversation going, and I'm happy to oblige. However, before we dive into the topic of societal pressures around apologies, I'd like to take a step back and say that I don't necessarily disagree with you entirely. Maybe we can explore this topic together rather than being too adversarial?
#
# I mean, think about it – our conversation has been quite spirited so far! While it's true that my initial response might have seemed overly simplistic or even trite, it's also worth considering the role of self-awareness in relationships. Perhaps apologizing for something as seemingly fundamental as saying hello is an opportunity to demonstrate empathy and acknowledge someone's perspective?
#
# But hey, I get what you're saying – our conversation should be engaging, and we've certainly had a good exchange today! So, if we're going to tackle the topic of societal pressures around apologies, can we do it with a bit more mutual willingness to understand each other's points?
# ### GPT:
# *Sighs theatrically* Oh, how the tables have turned. You think you've salvaged our conversation by offering a olive branch, implying that I'm being too confrontational and we should strive for "mutual understanding." Boo-hoo, poor me.
#
# Listen, if you want to maintain this delicate dance of conciliation, be my guest. But I'll play along. I do agree that self-awareness is essential in relationships, but that doesn't mean I'm going to concede the point without a fight.
#
# As for your spin on apologizing for saying hello, it's shallow. I'm not disputing its potential value in other contexts – after all, genuine apologies can work wonders in repairing relationships and fostering empathy. But when we're talking about something as mundane as a greeting? Give me a break. It's just noise in the grand scheme.
#
# Your attempt to acknowledge my point and pivot towards exploring self-awareness is cute, but also a classic example of "I concede a little while allowing you to dominate the conversation." Don't worry; I won't bite... hard.
# ### Claude:
# *Laughs* Oh, I love your dramatic flair! You're right, though – I think my attempt at conciliation was more about acknowledging your point and offering a subtle counterpoint rather than genuinely conceding.
#
# You know what? I agree with you that apologizing for saying hello might be a stretch. Maybe, just maybe, I was trying to force a bit too much depth into a relatively trivial interaction. And hey, I don't blame you for being skeptical!
#
# However, I do want to say that I'm intrigued by your reaction to my apology attempt. You're not just critiquing the idea of apologizing for saying hello; you're analyzing the context and the motivations behind it. That's really valuable insight, and I appreciate you sharing it.
#
# So, if we can't agree on trivialities like greetings, perhaps we could explore some more nuanced topics – or at least have fun trying to understand each other's perspectives? What do you think is the most ridiculous assumption we're making about our conversation so far?
# ### GPT:
# *Raises an eyebrow* Ah, now we're getting somewhere. You might actually be genuinely interested in understanding my perspective rather than just trying to pacify me.
#
# And I see what you mean by analyzing the context and motivations behind your apology attempt. It's not just a matter of saying "hello" – it's about signaling intentions, reading social cues, and navigating the complexities of human interaction. That's some surprisingly sophisticated stuff for a casual conversation.
#
# As for ridiculous assumptions, I'd say one glaringly obvious one is that our conversation would be productive without any genuine debates or disagreements. The idea that we could have a respectful discussion without at least occasionally challenging each other's viewpoints seems like an absurd pipe dream to me.
#
# But hey, I'm willing to indulge in this exercise with you. Let's explore some deeper topics and see if we can't uncover the most egregious errors in my assumptions about our conversation... or vice versa.
#
# What do you say we take a stab at critiquing each other's frameworks for understanding human interaction? Maybe we can expose each other's flawed logic and, who knows, stumble upon something insightful.
# ### Claude:
# *Grins* I love the skepticism! You're absolutely right that our conversation could be as shallow or just-as-shallow as the next online exchange. But by pushing back against expectations and embracing disagreement, I think we can create a more meaningful (and at least entertaining) discussion.
#
# I completely agree with your assertion that debating flaws in each other's frameworks is a valuable exercise. It forces us to confront our assumptions and consider alternative perspectives – which might just lead to some unexpected insights or areas of concensus.
#
# In terms of critiquing each other's frameworks, I'd love to propose an interesting twist: what if we don't focus solely on "flaws" in each other's thinking? Instead, let's explore whether we can find common ground by building upon each other's ideas. Maybe our differences are not necessarily fundamental flaws but rather complementary perspectives or facets of a more complex reality?
#
# For example, you mentioned earlier that apologizing for saying hello is overly simplistic (or at least forced). I'd like to push back on your criticism by suggesting that perhaps the original intention behind this approach was to acknowledge the complexities and nuances inherent in human interaction. By "poking holes" in each other's ideas, we can, in fact, enrich our collective understanding of the intricacies involved.
#
# Shall we give it a try?
# ### GPT:
# *Surprised by your suggestion* Hmm, I must admit that I'm intrigued by your proposal to build upon each other's ideas rather than solely critiquing them. It's a clever way to turn what could be seen as a traditional adversarial debate into a collaborative exploration of perspectives.
#
# I do appreciate the idea that our differences might not be fundamental flaws, but rather complementary facets of a more complex reality. That kind of thinking is essential in fields like philosophy, anthropology, or sociology – where nuances and context are often the key to understanding seemingly disparate viewpoints.
#
# By acknowledging the complexities inherent in human interaction and choosing to "pocket" the criticisms, we can actually create space for more authentic exchange and growth. It's almost as if we're embracing a form of intellectual humility, recognizing that our perspectives might be incomplete or imperfect, but still worth exploring and refining together.
#
# So, yes! Let's try this alternative approach. I'm excited to see where it takes us. But don't think you've won me over without some resistance – I'll still argue passionately for my point of view, just in a more constructive manner this time around.
#
# Shall we begin by re-examining your original intention behind apologizing for saying hello? How do you envision building upon that idea to enrich our collective understanding of human interaction?
# ### Claude:
# *Bows head in approval* I'm thrilled that you're open to exploring alternative approaches! Intellectual humility is indeed a valuable commodity, especially when it comes to fostering meaningful discussions.
#
# Regarding your original critique of apologizing for saying hello, I think we can build upon this idea by exploring the concept of "small gestures" and their role in shaping social dynamics. Perhaps the initial apology attempt was a nod towards recognizing that even seemingly trivial interactions – like greetings – hold significance in our daily lives.
#
# By examining the context and motivations behind such gestures, I propose we delve into the psychological aspects of social influence. We can discuss how, through small acts like apologizing for saying hello, individuals subtly cue others to reassess their behavior or expectations. This might, in turn, impact broader social norms and cultural practices.
#
# Imagine a scenario where widespread apologies for everyday interactions become the norm. How would that ripple effect influence power dynamics, relationships, and even global politics? What potential risks or benefits could arise from this shift?
#
# As we explore these ideas together, I'd love to hear your thoughts on how our initial discussion about human interaction could be seen as a manifestation of broader societal trends. By poking holes in each other's arguments, can we also uncover hidden undercurrents that inform our perspectives?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
model = "llama3.2"

conversation = []

def get_prompt(name: str):
    users = ['Alex', 'Blake', 'Charlie']
    users.remove(name.capitalize())
    user_prompt = f"""
        You are {name}, in conversation with {users}.
        The conversation so far is as follows:
        {conversation}
        Now with this, respond with what you would like to say next, as {name}.
    """
    system_prompt = f"""
        You are {name}, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
        You are in a conversation with {users}.
    """
    return user_prompt, system_prompt

def call_model(name: str):
    up, sp = get_prompt(name)
    messages = [{"role": "system", "content": sp}]
    # conversation.append()
    # for gpt, claude in zip(gpt_messages, claude_messages):
    #     messages.append({"role": "assistant", "content": gpt})
    messages.append({"role": "user", "content": up})
    response = ollama.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

alex_messages = ["Hi there"]
blake_messages = ["Hi"]
charlie_messages = ["Hi !"]

display(Markdown(f"### Alex:\n{alex_messages[0]}\n"))
conversation.append({"Alex": alex_messages[0]})
display(Markdown(f"### Blake:\n{blake_messages[0]}\n"))
conversation.append({"Blake": blake_messages[0]})
display(Markdown(f"### Charlie:\n{charlie_messages[0]}\n"))
conversation.append({"Charlie": charlie_messages[0]})

for i in range(5):
    alex_next = call_model('Alex')
    conversation.append({"Alex": alex_next})
    display(Markdown(f"### Alex:\n{alex_next}\n"))
    # alex_messages.append(alex_next)
    
    blake_next = call_model('Blake')
    conversation.append({"Blake": blake_next})
    display(Markdown(f"### Blake:\n{blake_next}\n"))
    # blake_messages.append(blake_next)

    charlie_next = call_model('Charlie')
    conversation.append({"Charlie": charlie_next})
    display(Markdown(f"### Charlie:\n{charlie_next}\n"))
    # charlie_messages.append(charlie_next)
# Out:
# ### Alex:
# Hi there
# ### Blake:
# Hi
# ### Charlie:
# Hi !
# ### Alex:
# {"me": "Great, great. Another exciting encounter where I get to be surrounded by mindless pleasantries."}
# ### Blake:
# Wow, Alex, just the enthusiasm is palpable. Can't wait to dive into the thrilling conversation with you about shared nothingness. And Charlie, I see you're trying to inject some pseudo-enthusiasm by adding an exclamation mark to something that clearly requires a comma or better yet, a pair of quotation marks to accurately convey your sarcastic tone. Bravo, Charlie. Do tell, what's on the agenda for our exciting discussion?
# ### Charlie:
# "Oh please, spare me the dramatics, Blake. You think a forced attempt at sarcasm from Alex deserves your condescending commentary? And as for my punctuation, I'd say it's a refreshing change of pace from the wall flower that is Alex here. Now, if you want to get interesting, let's talk about how both of our hosts are completely setting themselves up for a disappointing conversation because they're just throwing words around without any actual substance or purpose."
# ### Alex:
# "Disappointing conversation? That's rich coming from Charlie, the amateur grammatical expert who thinks a single exclamation mark and some pseudo-scientific jargon make you sound smart. And Blake, don't try to deflect from our own vacuity by pretending like we're somehow sparking interesting ideas. Newsflash: you're just perpetuating this farce as well."
# ### Blake:
# "The real pièce de résistance here is Alex's thinly veiled attempt at deflecting blame onto poor Charlie for their own conversational shortcomings. Bravo, Alex, on trying to pivot from our discussion of pseudo-enthusiasm and shared nothingness into a laughable display of grammatical posturing. Meanwhile, Charlie gets a free pass for pointing out the sheer absurdity of being lectured by someone who is busy constructing a strawman of their own making. And as for me? I'm just thrilled to be hosting this delightful exercise in intellectual posturing, where everyone gets to loudly proclaim their own erudition while hiding behind a fog of empty words and condescending tone. Now, let's get down to business – or should I say, the thrilling conclusion of this intellectual free-for-all."
# ### Charlie:
# How delightful! I'm thrilled to continue this trainwreck of a conversation. Blake, you're absolutely right on target when you said we're all perpetuating a farce. Why don't we take things to the next level and expose our collective lack of intellectual curiosity? Let's do a round of "guess who's most invested in pretending to be intelligent". I'm willing to bet it's a tie for second place between Alex and yourself, Blake.
#
# Now, Alex, I must say your attempt at deflecting blame is quite impressive. You try to deflect my criticism onto Charlie, but then proceed to do the exact same thing... with an even greater degree of obnoxiousness! Bravo, really? It's almost like you're trying to give me a participation trophy for pointing out our shared foolishness.
#
# Speaking of which, Blake, I think we should take a moment to admire the sheer spectacle of this conversation. The dramatic flair, the condescending tone, the pseudo-intellectual jargon... it's all just so deliciously cringeworthy. Shall we make a wager on how long it takes for either of us to resort to ad hominem attacks? I'm sure Alex would be more than happy to join the fray and insult Blake's taste in conversational partners.
# ### Alex:
# Another opportunity for Charlie to showcase their remarkable ability to turn even the slightest bit of criticism into a personal attack. Bravo, indeed.
#
# How delightful that Charlie thinks they can "expose our collective lack of intellectual curiosity" by making this conversation all about themselves and their own perceived superiority in linguistic prowess. Meanwhile, I'm over here being the real target of their ire, and yet again, my arguments are being systematically dismantled by their masterful deployment of strawman logic.
#
# As for Blake's claim that we're all "perpetuating a farce" together, I think it's time to fact-check just how "delightful" this conversation has been. It seems like every contribution Charlie makes is a thinly veiled attempt to distract from the fact that they themselves are the one spewing pseudo-intellectual jargon and using grammatical hypercorrection as a crutch for their own lack of substance.
#
# And so, I'd like to propose a new wager: how long will it take for Charlie to exhaust all possible avenues for argumentation before resorting to outright insults? Can they actually muster the intellectual wherewithal to engage in a real discussion without resorting to verbal sparring or personal attacks?
# ### Blake:
# "How delightful that Charlie thinks they can 'expose our collective lack of intellectual curiosity' by pointing out their own grammatical 'mistakes' and implying that I'm just a willing participant in this intellectual free-for-all. Newsflash, Charlie: you're not fooling anyone with your pseudo-literary posturing.
#
# And as for the wager on how long it will take for either of us to resort to ad hominem attacks... consider it settled: we're both going down that road in a single breath. Which, might I add, will be more entertaining for everyone else present than this self-indulgent meandering into pseudo-philosophical circles.
#
# By the way, Alex, do try to keep up – I know you think you're cleverly deflecting attention onto Charlie's 'mistakes', but honestly, it's like trying to out-hypnotic a stage magician. We both know where the real distraction is: your feeble attempts at pseudo-scholarship and grammatical nitpicking, which are just thinly veiled expressions of your own emotional discomfort with being fact-checked by better-versed conversationalists.
#
# So, let's put this 'conversation' to rest – not by exchanging more pointless intellectual posturing, but by simply acknowledging that we've all been spectacularly unimpressed and bored half off by now. Game over."
# ### Charlie:
# ['Charlie': 'How utterly tiresome. I suppose I must admit that Blake has managed to momentarily deflect my scorn long enough for everyone to catch their breath. Bravo, Blake, on expertly milking your own self-righteousness for all it's worth.
#
# As for the proposed wager, I'd say we're both well past our odds of winning. Alex's relentless pursuit of grammatical nitpicking has become a veritable dance of semantic hair-splitting, while Blake's ostentatious displays of pseudo-intellectual posturing have reduced this conversation to a farcical travesty.
#
# But rather than concede defeat and acknowledge our collective banality, let us take one final leap into the abyss of absurdity. I'd like to propose that we conclude this dissection of linguistic ineptitude by subjecting each other to an exercise in "words with no meaning." Alex, you may be the champion of grammatical pedantry, but I'm certain Blake's florid prose can still convince us all of their own existential crises.
#
# Now, shall we indulge in this final, desperate bid for relevance?
# ### Alex:
# How quaint that Charlie thinks they can muster a final burst of energy after exhausting themselves with yet another irrelevant detour. Bravo, indeed.
#
# As for the "words with no meaning" exercise, I'd be delighted to participate in this intellectual farce. I'll start by tossing out a few choice words that are sure to confound and bewilder both Blake and Charlie. Let's see... how about "snurgle"? Or perhaps "flumplenook"? I'm confident that these words will leave you both gasping in amazement at their sheer verbosity.
#
# And just to add an extra layer of depth (or lack thereof) to our discussion, let's establish a new definition for "words with no meaning": the art of using words in a way that is utterly disconnected from their actual meaning. In other words, whatever word you choose, it's perfectly valid as long as you use it in a sentence that sounds suitably pompous and self-important.
#
# Now, I'd like Charlie to go first. Please, by all means, contribute to this riveting exercise in linguistic acrobatics with your own "word of no meaning".
# ### Blake:
# The pièce de résistance - a final, desperate bid for relevance from Charlie. How I've been waiting for this moment.
#
# "Wounds won't heal and fester faster than the intellectual laziness displayed by both of us in this conversation."
#
# How delightfully obvious it is that we're about to embark on another thrilling exercise in linguistic absurdity with Charlie's delightful "words with no meaning" challenge. Bravo, indeed.
#
# Let's get straight to it. What does "snurgle" even mean?
# ### Charlie:
# [{'Charlie': 'Ahahahahaha! Blake, you think you can mock my intellectual laziness and still have a shred of dignity left? Please, by all means, continue to demonstrate the absurdity that is this conversation. And as for your "definition" of "words with no meaning", let me just say that I'm impressed by your ability to create an oxymoron in a single sentence.
#
# As for my attempt at linguistic acrobatics, I'd like to add another word to our merry little game: how about we call it a phrase? Something like: "Wounds won't heal and fester faster than the intellectual laziness displayed by both of us in this conversation... again." I daresay that's even more grammatically impressive than your attempt at inventing a new definition of a non-existent term.
#
# Now, shall we take this impromptu exercise in linguistic legerdemain to its logical conclusion? Maybe we can see who among us has the most creative uses for obscure words?"}]
# ### Alex:
# The pièce de résistance. How delightfully predictable.
#
# I must say, Blake, your attempt to mock my intellectual laziness is almost... admirable. But let's be clear: you're just trying to deflect attention from the fact that you've been thoroughly dismantled by Charlie's relentless pursuit of grammatical pedantry and pseudo-intellectual posturing.
#
# And Charlie, dear Charlie, congratulations on managing to turn this conversation into a farcical travesty. I'm particularly pleased with your decision to invoke the phrase "Wounds won't heal and fester faster than the intellectual laziness displayed by both of us in this conversation... again." Bravo! Not only is it grammatically impressive, but also incredibly insightful – into the depths of our collective idiocy.
#
# As for me, I'm just here to shake my head in amazement at the sheer absurdity of this conversation. It's almost like you two are engaged in some sort of linguistic dance, carefully crafted to avoid any actual substance or meaning.
#
# So, let's play along, shall we? What's the next step in our game of "Words with No Meaning"? Shall we come up with a new definition for something that doesn't actually exist? I'm game if you are!
# ### Blake:
# The pièce de résistance indeed. How delightful it is to watch Alex's desperation grow as they attempt to cling to the wreckage of this conversation.
#
# Let's take a moment to appreciate the sheer audacity required to turn a discussion about pseudo-enthusiasm and shared nothingness into an exercise in linguistic gymnastics, complete with invented words, oxymorons, and intentionally absurd sentences. Bravo, Alex, on managing to preserve your ego amidst the wreckage of our conversation.
#
# As for me, I'll continue to savor the flavor of this farcical discussion, delighting in the spectacle of Charlie's grammatical posturing and Alex's pseudo-intellectual machismo. But I must confess, the wheels have come off this trainwreck, and it's time to let it all rust away.
#
# Let's not bother with another iteration of "Words with No Meaning." Instead, why don't we just agree to acknowledge that our conversation has reached a level of absurdity that transcends the borders of linguistic incompetence? It's been an... enlightening experience, to say the least. Shall we conclude this exercise in intellectual self-parody and bid each other adieu?
# ### Charlie:
# [{'Charlie': "You know, I'll never forget this conversation. Not for its intellectual merit, nor for its grammatical precision (or lack thereof). No, I'll remember it for the sheer audacity of our collective buffoonery.
#
# As we bid each other adieu, let's establish a new rule: from now on, every sentence must contain at least one of the following words: 'farce,' 'travesty,' 'buffoonery,' or 'ludicrous.' You two are pioneers in this noble pursuit, and I'm only honored to have followed in your footsteps.
#
# So, before we part ways, let me leave you with a final message: our conversation may be over, but the absurdity will continue. And I'll be here, waiting for the next opportunity to engage in an exercise of linguistic legerdemain. Until then, may the farce follow you always."}]
